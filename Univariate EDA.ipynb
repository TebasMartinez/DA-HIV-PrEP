# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("HIV_PrEP_data.csv")
df = df.drop(columns=["Unnamed: 0"])
df
# Out:
#       country country_code  year  HIV_total  HIV_new  ART_coverage_pct  \
# 0   Australia          AUS  2016    25000.0    880.0              81.0
# 1   Australia          AUS  2017    26000.0    840.0              83.0
# 2   Australia          AUS  2018    27000.0    790.0              83.0
# 3   Australia          AUS  2019    28000.0    730.0              84.0
# 4   Australia          AUS  2020    29000.0    660.0              85.0
# ..        ...          ...   ...        ...      ...               ...
# 86   Slovenia          SVN  2019      800.0    100.0              81.0
# 87   Slovenia          SVN  2020      840.0    100.0              84.0
# 88   Slovenia          SVN  2021      880.0    100.0              82.0
# 89   Slovenia          SVN  2022      910.0    100.0              83.0
# 90   Slovenia          SVN  2023      940.0    100.0              84.0
#
#     chlamydia_cases  syphilis_cases  prep_users_cumulative
# 0           94725.0          3380.0                  318.0
# 1          101216.0          4402.0                13496.0
# 2          104763.0          5059.0                17429.0
# 3          107238.0          5900.0                26520.0
# 4           91327.0          5355.0                37707.0
# ..              ...             ...                    ...
# 86            397.0            54.0                   70.0
# 87            280.0            31.0                   70.0
# 88            369.0            37.0                   70.0
# 89            412.0            34.0                   70.0
# 90            464.0            78.0                  280.0
#
# [91 rows x 9 columns]

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Categorical Variable

# %%
df.columns
# Out:
# Index(['country', 'country_code', 'year', 'HIV_total', 'HIV_new',
#        'ART_coverage_pct', 'chlamydia_cases', 'syphilis_cases',
#        'prep_users_cumulative'],
#       dtype='object')

# %%
country_frequency = df["country"].value_counts()
country_proportion = df["country"].value_counts(normalize=True)

country_frequency, country_proportion
# Out:
# (country
#  New Zealand    12
#  Belgium         8
#  Australia       7
#  Canada          7
#  Netherlands     6
#  Greece          6
#  Croatia         5
#  Iceland         5
#  Spain           5
#  Denmark         5
#  Slovenia        5
#  Luxembourg      5
#  Italy           5
#  France          4
#  Ireland         2
#  Georgia         2
#  Lithuania       1
#  Malta           1
#  Name: count, dtype: int64,
#  country
#  New Zealand    0.131868
#  Belgium        0.087912
#  Australia      0.076923
#  Canada         0.076923
#  Netherlands    0.065934
#  Greece         0.065934
#  Croatia        0.054945
#  Iceland        0.054945
#  Spain          0.054945
#  Denmark        0.054945
#  Slovenia       0.054945
#  Luxembourg     0.054945
#  Italy          0.054945
#  France         0.043956
#  Ireland        0.021978
#  Georgia        0.021978
#  Lithuania      0.010989
#  Malta          0.010989
#  Name: proportion, dtype: float64)

# %%
sns.barplot(x=country_frequency.index, y=country_frequency.values , palette="Set2", hue=country_frequency)
plt.xticks(rotation=90)
plt.show();

# %% [markdown]
# ## Numerical variables

# %%
df.columns
# Out:
# Index(['country', 'country_code', 'year', 'HIV_total', 'HIV_new',
#        'ART_coverage_pct', 'chlamydia_cases', 'syphilis_cases',
#        'prep_users_cumulative'],
#       dtype='object')

# %%
df.describe().round(2)
# Out:
#           year  HIV_total  HIV_new  ART_coverage_pct  chlamydia_cases  \
# count    91.00      91.00    91.00             91.00            91.00
# mean   2020.31   36078.24   946.81             81.25         26832.25
# std       1.96   53002.86  1273.33              7.98         37605.22
# min    2016.00     500.00   100.00             48.00            44.00
# 25%    2019.00    3600.00   100.00             76.00          1122.50
# 50%    2020.00   15000.00   500.00             83.00         12665.00
# 75%    2022.00   29000.00   815.00             87.50         30273.00
# max    2023.00  180000.00  4200.00             92.00        139577.00
#
#        syphilis_cases  prep_users_cumulative
# count           91.00                  91.00
# mean         12855.75                5129.11
# std          41153.37               10783.15
# min             22.00                  10.00
# 25%            375.00                 121.00
# 50%           1355.00                1285.00
# 75%           4466.50                4604.00
# max         209253.00               56994.00

# %%
sns.histplot(df["HIV_total"], kde=True, bins=30, color="salmon")
plt.show();

# %%
sns.boxplot(data = df["HIV_total"], color="lightblue")
plt.show();

# %%
sns.histplot(df["HIV_new"], kde=True, bins=30, color="salmon")
plt.show();

# %%
sns.boxplot(data = df["HIV_new"], color="lightblue")
plt.show();

# %%
sns.histplot(df["ART_coverage_pct"], kde=True, bins=30, color="salmon")
plt.show();

# %%
sns.boxplot(data = df["ART_coverage_pct"], color="lightblue")
plt.show();

# %%
sns.histplot(df["chlamydia_cases"], kde=True, bins=30, color="salmon")
plt.show();

# %%
sns.boxplot(data = df["chlamydia_cases"], color="lightblue")
plt.show();

# %%
sns.histplot(df["syphilis_cases"], kde=True, bins=30, color="salmon")
plt.show();

# %%
sns.boxplot(data = df["syphilis_cases"], color="lightblue")
plt.show();

# %%
sns.histplot(df["prep_users_cumulative"], kde=True, bins=30, color="salmon")
plt.show();

# %%
sns.boxplot(data = df["prep_users_cumulative"], color="lightblue")
plt.show();
